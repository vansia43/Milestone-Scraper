# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install BeautifulSoup4
# !{sys.executable} -m pip install selenium
# Out:
# ...
# You are using pip version 9.0.1, however version 20.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 20.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
import re
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
url = "https://github.com/getting-things-gnome/gtg/milestone/3?closed=1"
DRIVER_PATH = '/Users/dani/code/chromedriver'

# %%
options = Options()
options.headless = True
driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
driver.get(url)
time.sleep(10)
page = driver.page_source

# %%
soup = BeautifulSoup(page, "html.parser")
containers = soup.find_all("div", {"class": "flex-auto min-width-0 p-2"})

# %%
for con in containers: 
    print (con.a.text)
    link = con.a['href']
    print ("https://github.com"+link)
    num = re.findall(r'\d+', link)
    print(num[0])
    print(" ")
    link = ""
# Out:
# Document the standard keyboard shortcuts to fold/unfold treeview items
# https://github.com/getting-things-gnome/gtg/issues/408
# 408
#
# Ability to "Add a parent task" to a task
# https://github.com/getting-things-gnome/gtg/pull/517
# 517
#
# Swedish translation
# https://github.com/getting-things-gnome/gtg/pull/495
# 495
#
# Update german translation
# https://github.com/getting-things-gnome/gtg/pull/500
# 500
#
# Renaming subtask causes text to duplicate
# https://github.com/getting-things-gnome/gtg/issues/450
# 450
#
# Child task gets removed when closing their editor while the parent task editor is open
# https://github.com/getting-things-gnome/gtg/issues/496
# 496
#
# Can't translate current recurring state
# https://github.com/getting-things-gnome/gtg/issues/490
# 490
#
# Fix current recurring state translation issue
# https://github.com/getting-things-gnome/gtg/pull/498
# 498
#
# Update websites and contributors documentation
# ...
